# %% [markdown]
# # Orchestration Logic

# %%
notebooks = [
  "./gold_dim_customers",
  "./gold_dim_products",
  "./gold_dim_fact_sales"
]

for nb in notebooks:
  print(f"running {nb}")
  dbutils.notebook.run (nb, timeout_seconds=0)
